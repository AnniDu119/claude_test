# %%
class Car:
    def __init__(self, brand, model, year):
        # Constructor - runs when creating a new object
        self.brand = brand
        self.model = model
        self.year = year
    
    def describe(self):
        # Instance method
        return f"{self.year} {self.brand} {self.model}"
    
    def start_engine(self):
        # Another instance method
        return f"{self.brand} engine started!"

# Creating objects (instances) of the Car class
car1 = Car("Toyota", "Camry", 2023)
car2 = Car("Honda", "Civic", 2024)

# Accessing attributes
print(car1.brand)  # Output: Toyota
print(car2.year)   # Output: 2024

# Calling methods
print(car1.describe())      # Output: 2023 Toyota Camry
print(car2.start_engine())  # Output: Honda engine started!
# Out:
# Toyota
# 2024
# 2023 Toyota Camry
# Honda engine started!
